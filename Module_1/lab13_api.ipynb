# %%
from PIL import Image
import json
import requests
import pandas as pd
from io import BytesIO

# %%
url = "https://xkcd.com"
image_url = "https://imgs.xkcd.com/comics/fuck_grapefruit.png"
response = requests.get(url)
headers = response.headers
print(headers)
expires = response.headers['Expires']
print(expires)

img_res = requests.get(image_url)
img = Image.open(BytesIO(img_res.content))
img.save('fruits.png')
Image.open(BytesIO(img_res.content))

with open('xkcd.html', 'w') as file:
    file.write(response.content.decode('utf-8'))
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2685', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Wed, 25 Jan 2023 19:57:29 GMT', 'ETag': 'W/"63d189a9-1ba0"', 'Expires': 'Wed, 25 Jan 2023 20:03:06 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 25 Jan 2023 21:46:23 GMT', 'Age': '187', 'X-Served-By': 'cache-dfw-kdfw8210121-DFW, cache-cdg20720-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '76, 1', 'X-Timer': 'S1674683183.046414,VS0,VE1', 'Vary': 'Accept-Encoding'}
# Wed, 25 Jan 2023 20:03:06 GMT

# %%
url_bin = "https://httpbin.org/get"
payload = {'things':2,'total':25}
response_bin = requests.get(url_bin, params = payload)
response_bin
print(response_bin.url)

p_up = {'username':'t','passwords':'null'}
response_up = requests.get(url_bin, params = p_up)
response_up.json()['args']
# Out:
# https://httpbin.org/get?things=2&total=25
# {'passwords': 'null', 'username': 't'}

# %%
# url_git = 'https://github.com/ironhack-datalabs/scavenger'
# res_git = requests.get(url_git)
# res_git.json()

# https://github.com/ironhack-datalabs/scavenger
# https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger

response = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
# f_search = pd.json_normalize(search)
# f_search

# %%
data = pd.DataFrame(search['items']).sort_values(by = 'name')
data
# Out:
#                    name                       path  \
# 10  .0001.scavengerhunt  98750/.0001.scavengerhunt
# 5   .0002.scavengerhunt  88596/.0002.scavengerhunt
# 18  .0003.scavengerhunt  60224/.0003.scavengerhunt
# 21  .0004.scavengerhunt  68848/.0004.scavengerhunt
# 13  .0005.scavengerhunt  44639/.0005.scavengerhunt
# 7   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 17  .0007.scavengerhunt  17020/.0007.scavengerhunt
# 23  .0008.scavengerhunt  15534/.0008.scavengerhunt
# 1   .0009.scavengerhunt  97881/.0009.scavengerhunt
# 20  .0010.scavengerhunt  47830/.0010.scavengerhunt
# 6   .0011.scavengerhunt  50896/.0011.scavengerhunt
# 9   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 12  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 8   .0014.scavengerhunt  49418/.0014.scavengerhunt
# 16  .0015.scavengerhunt  91701/.0015.scavengerhunt
# 0   .0016.scavengerhunt  47222/.0016.scavengerhunt
# 22  .0017.scavengerhunt  70985/.0017.scavengerhunt
# ...

# %%
# from urllib.request import urlopen

# f = urlopen(link for link in data['html_url'])
# myfile = f.read()
# print(myfile)

joke_list = []
for i in range(24):
    response_git = requests.get(data['url'][i])
    joke_list.append(response_git.json()['content'])

joke_list

import base64
message = [base64.b64decode(b64message).decode('ascii') for b64message in joke_list]
message
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/thaopham/Documents/dev/lab13_api.ipynb Cell 6 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/Users/thaopham/Documents/dev/lab13_api.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> for i in range(24):
#       <a href='vscode-notebook-cell:/Users/thaopham/Documents/dev/lab13_api.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a>     response_git = requests.get(data['url'][i])
# ---> <a href='vscode-notebook-cell:/Users/thaopham/Documents/dev/lab13_api.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     joke_list.append(response_git.json()['content'])
#      <a href='vscode-notebook-cell:/Users/thaopham/Documents/dev/lab13_api.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> joke_list
#
# KeyError: 'content'

# %%
# f = urlopen(data["html_url"][0])
# myfile = f.read()

# %%
# print(myfile)

# %%
# Teacher's method:

search["items"]
# Out:
# [{'name': '.0016.scavengerhunt',
#   'path': '47222/.0016.scavengerhunt',
#   'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#   'repository': {'id': 162375181,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#    'name': 'scavenger',
#    'full_name': 'ironhack-datalabs/scavenger',
#    'private': False,
#    'owner': {'login': 'ironhack-datalabs',
#     'id': 44225188,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ironhack-datalabs',
# ...

# %%
repo_files_names = [item["name"] for item in search["items"]]
repo_files_names.sort()
repo_files_names
# Out:
# ['.0001.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0006.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0012.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0024.scavengerhunt']

# %%
repo_files_urls = {item["name"]: item["url"] for item in search["items"]}
repo_files_urls
# Out:
# {'.0016.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0009.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/97881/.0009.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0021.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/30351/.0021.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0023.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/55417/.0023.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0019.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/70751/.0019.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0002.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/88596/.0002.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
# ...

# %%
repo_files = [requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files_names]
repo_files
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
repo_files_content = [file.json()["content"] for file in repo_files]
repo_files_content
# Out:
# ['SW4K\n',
#  'ZGF0YQo=\n',
#  'c2NpZW5jZSwK\n',
#  'ODAK\n',
#  'cGVyY2VudAo=\n',
#  'b2YK\n',
#  'dGltZQo=\n',
#  'c3BlbnQK\n',
#  'aXMK\n',
#  'cHJlcGFyaW5nCg==\n',
#  'ZGF0YSwK\n',
#  'MjAK\n',
#  'cGVyY2VudAo=\n',
#  'b2YK\n',
#  'dGltZQo=\n',
#  'aXMK\n',
#  'c3BlbnQK\n',
#  'Y29tcGxhaW5pbmcK\n',
#  'YWJvdXQK\n',
#  'dGhlCg==\n',
#  'bmVlZAo=\n',
#  'dG8K\n',
#  'cHJlcGFyZQo=\n',
#  'ZGF0YS4K\n']

# %%
import base64
message = [base64.b64decode(b64message).decode('ascii') for b64message in repo_files_content]
message
# Out:
# ['In\n',
#  'data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  '20\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n',
#  'data.\n']

# %%
print(''.join(message).replace("/n"," "))
